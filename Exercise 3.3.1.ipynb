# %%
library("tidyverse")
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.2.1     v purrr   0.3.3
# v tibble  2.1.3     v dplyr   0.8.3
# v tidyr   1.0.0     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
1.)What's gone wrong with this code?Why are the points not blue?

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x = displ, y =hwy, color = "blue"))
# Out:
# plot without title

# %%
The points are not blue as the argument for the geom function has not been set manually to go outside of aes()

# %%
2.)Which variable in mpg are categorical?Which variables are continous?
categorical variables-manufacturer,model,trans,drv,fl,class
continous variables-displ,year,cyl,cty,hwy

# %%
mpg

# %%
3)Map continous variable to color,size and shape.How do these aesthetics behave differently for categorical vs. continous variables?
The color aesthetics varies from light to dark in intesity,as the size also increases in size but for shape it returns an error as shown below.

# %%
ggplot(data =mpg) +
geom_point(mapping = aes(x = displ, y = hwy, colour=cyl))
# Out:
# plot without title

# %%
ggplot(data =mpg) +
geom_point(mapping = aes(x = displ, y = hwy, size= cty))
# Out:
# plot without title

# %%
ggplot(data =mpg) +
geom_point(mapping = aes(x = displ, y = hwy, shape = year))
# Out:
# ERROR while rich displaying an object: Error: A continuous variable can not be mapped to shape
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# ...

# %%
4)What happens if you map the same variable to multiple aesthetics?

# %%
ggplot(data = mpg)+
geom_point(mapping = aes(x= displ, y = hwy, colour = cty, size = cty))
# Out:
# plot without title

# %%
ggplot(data = mpg)+
geom_point(mapping = aes(x= displ, y = hwy, colour = drv, shape = drv))
# Out:
# plot without title

# %%
5.)What does the stroke aesthetic do? What shapes does it work with? he stroke aesthetic to modify the width of the(Hint: use ?geom_point) 
he stroke aesthetic is used to modify the width of the border for filled shapes(21-24)

# %%
ggplot

# %%
6.)What happens if you map an aesthetic to something other than a variable name, like aes(colour = displ < 5)? Note, you’ll also need to specify x and y.
gplot turns displ < 5 into a boolean variable and maps that True or False to the colour argument

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x= displ, y =hwy, colour = displ < 5))
# Out:
# plot without title
